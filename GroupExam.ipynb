# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import mglearn

# %%
df = pd.read_csv('elektronisk-rapportering-ers-2018-fangstmelding-dca-simple.csv', delimiter=';')
df.head()
# Out:
#    Melding ID Meldingstidspunkt Meldingsdato Meldingsklokkeslett  \
# 0     1497177        01.01.2018   01.01.2018               00:00
# 1     1497178        01.01.2018   01.01.2018               00:00
# 2     1497178        01.01.2018   01.01.2018               00:00
# 3     1497178        01.01.2018   01.01.2018               00:00
# 4     1497178        01.01.2018   01.01.2018               00:00
#
#      Starttidspunkt   Startdato Startklokkeslett Startposisjon bredde  \
# 0        31.12.2017  31.12.2017            00:00               -60,35
# 1  30.12.2017 23:21  30.12.2017            23:21               74,885
# 2  30.12.2017 23:21  30.12.2017            23:21               74,885
# 3  30.12.2017 23:21  30.12.2017            23:21               74,885
# 4  30.12.2017 23:21  30.12.2017            23:21               74,885
#
#   Startposisjon lengde  Hovedområde start (kode)  ...        Art - FDIR  \
# 0              -46,133                       NaN  ...  Antarktisk krill
# ...

# %%
columns_to_remove = [
    "Melding ID", "Meldingstidspunkt", "Meldingsdato", "Meldingsklokkeslett",
    "Starttidspunkt", "Startposisjon bredde", "Startposisjon lengde",
    "Hovedområde start (kode)", "Stopptidspunkt", "Stoppdato", "Stoppklokkeslett",
    "Fangstår", "Stopposisjon bredde", "Stopposisjon lengde",
    "Hovedområde stopp (kode)", "Redskap FAO (kode)", "Redskap FAO",
    "Redskap FDIR (kode)", "Hovedart FAO (kode)", "Hovedart FAO",
    "Hovedart - FDIR (kode)", "Art FAO (kode)", "Art - FDIR (kode)",
    "Art - FDIR", "Art - gruppe (kode)", "Art - gruppe", "Lengdegruppe",
    "Bruttotonnasje 1969", "Bruttotonnasje annen"
]

# Remove the specified columns from the DataFrame
df = df.drop(columns=columns_to_remove)

# Display the DataFrame after removing the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305434 entries, 0 to 305433
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Startdato              305434 non-null  object
#  1   Startklokkeslett       305434 non-null  object
#  2   Hovedområde start      301310 non-null  object
#  3   Lokasjon start (kode)  303433 non-null  float64
#  4   Havdybde start         305434 non-null  int64
#  5   Varighet               305434 non-null  int64
#  6   Hovedområde stopp      301310 non-null  object
#  7   Lokasjon stopp (kode)  303472 non-null  float64
#  8   Havdybde stopp         305434 non-null  int64
#  9   Trekkavstand           305410 non-null  float64
#  10  Redskap FDIR           305246 non-null  object
#  11  Art FAO                300452 non-null  object
#  12  Rundvekt               300456 non-null  float64
#  13  Lengdegruppe (kode)    304750 non-null  float64
# ...

# %%
columns_to_check = ['Bredde', 'Fartøylengde']  # Specify columns to check
df[columns_to_check] = df[columns_to_check].apply(pd.to_numeric, errors='coerce')

# Step 2: Identify invalid rows
invalid_rows = df[df[columns_to_check].isna().any(axis=1)]

# Step 3: Drop invalid rows
cleaned_df = df.dropna(subset=columns_to_check)

# Display information about the cleaned DataFrame
cleaned_df.head()
# Out:
#       Startdato Startklokkeslett Hovedområde start  Lokasjon start (kode)  \
# 130  01.01.2018            00:06    Nordkappbanken                   11.0
# 131  01.01.2018            00:06    Nordkappbanken                   11.0
# 132  01.01.2018            00:06    Nordkappbanken                   11.0
# 133  01.01.2018            00:06    Nordkappbanken                   11.0
# 134  01.01.2018            00:06    Nordkappbanken                   11.0
#
#      Havdybde start  Varighet Hovedområde stopp  Lokasjon stopp (kode)  \
# 130            -267       312    Nordkappbanken                   11.0
# 131            -267       312    Nordkappbanken                   11.0
# 132            -267       312    Nordkappbanken                   11.0
# 133            -267       312    Nordkappbanken                   11.0
# 134            -267       312    Nordkappbanken                   11.0
#
#      Havdybde stopp  Trekkavstand Redskap FDIR       Art FAO  Rundvekt  \
# ...
